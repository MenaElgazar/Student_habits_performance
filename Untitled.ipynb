# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds=pd.read_csv("student_habits_performance.csv", encoding="ISO-8859-1")
ds
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
ds.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
ds.tail()
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 995            1.6            No                   77.0          7.5
# 996            2.4           Yes                   86.0          6.8
# 997            1.3            No                   61.9          6.5
# 998            1.1           Yes                  100.0          7.6
# 999            1.9            No                   89.4          7.1
#
#     diet_quality  exercise_frequency parental_education_level  \
# 995         Fair                   2              High School
# ...

# %%
ds.shape
# Out:
# (1000, 16)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
# ...

# %%
ds.dtypes
# Out:
# student_id                        object
# age                                int64
# gender                            object
# study_hours_per_day              float64
# social_media_hours               float64
# netflix_hours                    float64
# part_time_job                     object
# attendance_percentage            float64
# sleep_hours                      float64
# diet_quality                      object
# exercise_frequency                 int64
# parental_education_level          object
# internet_quality                  object
# mental_health_rating               int64
# extracurricular_participation     object
# exam_score                       float64
# dtype: object

# %% [markdown]
# ds.nunique()

# %%
ds['gender'].unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
ds['part_time_job'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
ds['diet_quality'].unique()
# Out:
# array(['Fair', 'Good', 'Poor'], dtype=object)

# %%
ds['parental_education_level'].unique()
# Out:
# array(['Master', 'High School', 'Bachelor', nan], dtype=object)

# %%
count = (ds['gender'] == 'Other').sum()
count
# Out:
# np.int64(42)

# %%
ds['internet_quality'].unique()
# Out:
# array(['Average', 'Poor', 'Good'], dtype=object)

# %%
ds['extracurricular_participation'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
ds.describe()
# Out:
#              age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  1000.0000           1000.00000         1000.000000    1000.000000
# mean     20.4980              3.55010            2.505500       1.819700
# std       2.3081              1.46889            1.172422       1.075118
# min      17.0000              0.00000            0.000000       0.000000
# 25%      18.7500              2.60000            1.700000       1.000000
# 50%      20.0000              3.50000            2.500000       1.800000
# 75%      23.0000              4.50000            3.300000       2.525000
# max      24.0000              8.30000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count            1000.000000  1000.000000         1000.000000
# mean               84.131700     6.470100            3.042000
# std                 9.399246     1.226377            2.025423
# ...

# %%
ds.isnull().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
ds.dropna()
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
ds.drop_duplicates()
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
ds
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
ds.dropna(inplace=True)

# %%
ds
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
ds = ds.drop(ds[ds['gender'] == 'Other'].index)

# %%
ds
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
ds['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
sns.boxplot(ds['study_hours_per_day'])
# Out:
# <Axes: ylabel='study_hours_per_day'>

# %%
Q1 = ds['study_hours_per_day'].quantile(0.25)
Q3 = ds['study_hours_per_day'].quantile(0.75)
IQR= Q3-Q1
upper_limit= Q3 + 1.5 * IQR
lower_limit= Q1 - 1.5 * IQR
study_hours_per_day = ds[(ds['study_hours_per_day']> upper_limit) | (ds['study_hours_per_day']< lower_limit)]
study_hours_per_day.count()
# Out:
# student_id                       3
# age                              3
# gender                           3
# study_hours_per_day              3
# social_media_hours               3
# netflix_hours                    3
# part_time_job                    3
# attendance_percentage            3
# sleep_hours                      3
# diet_quality                     3
# exercise_frequency               3
# parental_education_level         3
# internet_quality                 3
# mental_health_rating             3
# extracurricular_participation    3
# exam_score                       3
# dtype: int64

# %%
ds = ds.drop(study_hours_per_day.index)
ds
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
sns.boxplot(data=ds['social_media_hours'])
# Out:
# <Axes: ylabel='social_media_hours'>

# %%
Q1 = ds['social_media_hours'].quantile(0.25)
Q3 = ds['social_media_hours'].quantile(0.75)
IQR= Q3-Q1
upper_limit= Q3 + 1.5 * IQR
lower_limit= Q1 - 1.5 * IQR
social_media_hours_outliers = ds[(ds['social_media_hours']> upper_limit) | (ds['social_media_hours']< lower_limit)]
social_media_hours_outliers.count()
# Out:
# student_id                       4
# age                              4
# gender                           4
# study_hours_per_day              4
# social_media_hours               4
# netflix_hours                    4
# part_time_job                    4
# attendance_percentage            4
# sleep_hours                      4
# diet_quality                     4
# exercise_frequency               4
# parental_education_level         4
# internet_quality                 4
# mental_health_rating             4
# extracurricular_participation    4
# exam_score                       4
# dtype: int64

# %%
ds = ds.drop(social_media_hours_outliers.index)
ds
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
sns.boxplot(ds['netflix_hours'])
# Out:
# <Axes: ylabel='netflix_hours'>

# %%
Q1 = ds['netflix_hours'].quantile(0.25)
Q3 = ds['netflix_hours'].quantile(0.75)
IQR= Q3-Q1
upper_limit= Q3 + 1.5 * IQR
lower_limit= Q1 - 1.5 * IQR
netflix_hours_outliers = ds[(ds['netflix_hours']> upper_limit) | (ds['netflix_hours']< lower_limit)]
netflix_hours_outliers.count()
# Out:
# student_id                       2
# age                              2
# gender                           2
# study_hours_per_day              2
# social_media_hours               2
# netflix_hours                    2
# part_time_job                    2
# attendance_percentage            2
# sleep_hours                      2
# diet_quality                     2
# exercise_frequency               2
# parental_education_level         2
# internet_quality                 2
# mental_health_rating             2
# extracurricular_participation    2
# exam_score                       2
# dtype: int64

# %%
ds=ds.drop(netflix_hours_outliers.index)
ds
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
sns.boxplot(data=ds['attendance_percentage'])
# Out:
# <Axes: ylabel='attendance_percentage'>

# %%
Q1 = ds['attendance_percentage'].quantile(0.25)
Q3 = ds['attendance_percentage'].quantile(0.75)
IQR= Q3-Q1
upper_limit= Q3 + 1.5 * IQR
lower_limit= Q1 - 1.5 * IQR
attendance_percentage_outliers = ds[(ds['attendance_percentage']> upper_limit) | (ds['attendance_percentage']< lower_limit)]
attendance_percentage_outliers.count()
# Out:
# student_id                       3
# age                              3
# gender                           3
# study_hours_per_day              3
# social_media_hours               3
# netflix_hours                    3
# part_time_job                    3
# attendance_percentage            3
# sleep_hours                      3
# diet_quality                     3
# exercise_frequency               3
# parental_education_level         3
# internet_quality                 3
# mental_health_rating             3
# extracurricular_participation    3
# exam_score                       3
# dtype: int64

# %%
ds=ds.drop(attendance_percentage_outliers.index)
ds
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
ds
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
sns.boxplot(data=ds['sleep_hours'])
# Out:
# <Axes: ylabel='sleep_hours'>

# %%
Q1 = ds['sleep_hours'].quantile(0.25)
Q3 = ds['sleep_hours'].quantile(0.75)
IQR= Q3-Q1
upper_limit= Q3 + 1.5 * IQR
lower_limit= Q1 - 1.5 * IQR
sleep_hours_outliers = ds[(ds['sleep_hours']> upper_limit) | (ds['sleep_hours']< lower_limit)]
sleep_hours_outliers.count()
# Out:
# student_id                       1
# age                              1
# gender                           1
# study_hours_per_day              1
# social_media_hours               1
# netflix_hours                    1
# part_time_job                    1
# attendance_percentage            1
# sleep_hours                      1
# diet_quality                     1
# exercise_frequency               1
# parental_education_level         1
# internet_quality                 1
# mental_health_rating             1
# extracurricular_participation    1
# exam_score                       1
# dtype: int64

# %%
ds=ds.drop(sleep_hours_outliers.index)
ds
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
sns.boxplot(data=ds['exercise_frequency'])
# Out:
# <Axes: ylabel='exercise_frequency'>

# %%
Q1 = ds['exercise_frequency'].quantile(0.25)
Q3 = ds['exercise_frequency'].quantile(0.75)
IQR= Q3-Q1
upper_limit= Q3 + 1.5 * IQR
lower_limit= Q1 - 1.5 * IQR
exercise_frequency_outliers = ds[(ds['exercise_frequency']> upper_limit) | (ds['exercise_frequency']< lower_limit)]
exercise_frequency_outliers.count()
# Out:
# student_id                       0
# age                              0
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# diet_quality                     0
# exercise_frequency               0
# parental_education_level         0
# internet_quality                 0
# mental_health_rating             0
# extracurricular_participation    0
# exam_score                       0
# dtype: int64

# %%
sns.boxplot(data=ds['mental_health_rating'])
# Out:
# <Axes: ylabel='mental_health_rating'>

# %%
sns.boxplot(data=ds['exam_score'])
# Out:
# <Axes: ylabel='exam_score'>

# %%
Q1 = ds['exam_score'].quantile(0.25)
Q3 = ds['exam_score'].quantile(0.75)
IQR= Q3-Q1
upper_limit= Q3 + 1.5 * IQR
lower_limit= Q1 - 1.5 * IQR
exam_score_outliers = ds[(ds['exam_score']> upper_limit) | (ds['exam_score']< lower_limit)]
exam_score_outliers.count()
# Out:
# student_id                       2
# age                              2
# gender                           2
# study_hours_per_day              2
# social_media_hours               2
# netflix_hours                    2
# part_time_job                    2
# attendance_percentage            2
# sleep_hours                      2
# diet_quality                     2
# exercise_frequency               2
# parental_education_level         2
# internet_quality                 2
# mental_health_rating             2
# extracurricular_participation    2
# exam_score                       2
# dtype: int64

# %%
ds=ds.drop(exam_score_outliers.index)
ds
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
ds.to_csv('student_habits_performancecleaned.csv', index=False)
ds
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...
